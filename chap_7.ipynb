# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()
# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %%
plt.figure(figsize=(4,3), facecolor="white")

# data
X = [1,2,3]
Y = [10,1,4]

# bar
plt.bar(X, Y, align="center")
plt.xticks(X, ['A Class','B Class','C Class'])

plt.xlabel("Class")
plt.ylabel("Score")
plt.grid(True)

# %%
# Fig size and background color
plt.figure(figsize=(4,3), facecolor="white")

X = [1,2,3]
Y = [10,1,4]

plt.barh(X,Y, align="center")
plt.yticks(X, ['A Class','B Class','C Class'])
plt.ylabel("Class")
plt.xlabel("Score")
plt.grid(True)

# %%
plt.figure(figsize=(4,3),facecolor="white")

Y1 = np.array([30,10,40])
Y2 = np.array([10,50,90])

X = np.arange(len(Y1))

# width
w = 0.4

plt.bar(X, Y1, color='b', width=w, label='Math first', align="center")
plt.bar(X + w, Y2, color='g', width=w, label='Math final', align="center")

# place the legend in the best place
plt.legend(loc="best")

plt.xticks(X + w/2, ['Class A','Class B','Class C'])
plt.grid(True)

# %%
plt.figure(figsize=(7,3),facecolor="white")

left = np.array([1, 2, 3, 4, 5])

height1 = np.array([100, 200, 300, 400, 500])
height2 = np.array([1000, 800, 600, 400, 200])

p1 = plt.bar(left, height1, color="blue")
p2 = plt.bar(left, height2, bottom=height1, color="lightblue")

plt.legend((p1[0], p2[0]), ("Class 1", "Class 2"))

# %%
plt.figure(figsize=(5,3),facecolor="white")

labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.1, 0, 0) 

# startangle=90 means "start from top and move counterclockwise"
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
# Out:
# (-1.2142507666786346,
#  1.134711077927507,
#  -1.1258468317413044,
#  1.101230806657754)

# %%
plt.figure(figsize=(5,3), facecolor="white")

N = 25

# X,Y axes
x = np.random.rand(N)
y = np.random.rand(N)

# color num
colors = np.random.rand(N)

# bubble size
area = 10 * np.pi * (15 * np.random.rand(N)) ** 2

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.grid(True)

# %%
x
# Out:
# array([0.712, 0.667, 0.488, 0.276, 0.376, 0.021, 0.205, 0.484, 0.124,
#        0.756, 0.468, 0.372, 0.179, 0.376, 0.94 , 0.927, 0.995, 0.172,
#        0.014, 0.95 , 0.519, 0.301, 0.169, 0.912, 0.552])

# %%
# R7-1

# %%
cd chap3
# Out:
# /Users/kei/Documents/Data_Science/TokyoU_DS/Data Science Study/chap3

# %%
ls
# Out:
# student-mat.csv  student-merge.R  student-por.csv  student.txt

# %%
df_m = pd.read_csv('student-mat.csv', sep=';')
df_m.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
s = df_m.groupby('reason').size()
s
# Out:
# reason
# course        145
# home          109
# other          36
# reputation    105
# dtype: int64

# %%
s.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.ylabel('')
plt.axis('equal')
# Out:
# (-1.1193776980870564,
#  1.1102745524399802,
#  -1.1043131643562698,
#  1.1002054024801953)

# %%
# R7-2
s2 = df_m.groupby('higher')['G3'].mean()
s2
# Out:
# higher
# no      6.800
# yes    10.608
# Name: G3, dtype: float64

# %%
s2.plot(kind='bar')
plt.xlabel('higher')
plt.ylabel('G3 grade avg')
# Out:
# Text(0, 0.5, 'G3 grade avg')

# %%
s3 = df_m.groupby('traveltime')['G3'].mean()
s3
# Out:
# traveltime
# 1    10.782101
# 2     9.906542
# 3     9.260870
# 4     8.750000
# Name: G3, dtype: float64

# %%
s3.plot(kind='barh')
plt.xlabel('G3 grade avg')
# Out:
# Text(0.5, 0, 'G3 grade avg')
